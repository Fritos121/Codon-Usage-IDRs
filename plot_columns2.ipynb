# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

in_fh = r"D:\Orthologs\Ortholog_Codon_Dist\PTHR42792\P04949_ortholog_msa_scores2.data"

df = pd.read_csv(in_fh)

# %%
# remove columns with no information
df_clean = df[df.Identity != 'X']
df_clean

# convert values in columns Percent ID and on to floats
df_clean[df_clean.columns[1:]] = df_clean[df_clean.columns[1:]].astype('float')

# %%
# matplotlib backend to plot dataframe
df_clean.plot.scatter('Avg Frequency Score', 'Avg Blosum62 Score', title='Per Column Scores')
df_clean.plot.scatter('Avg Frequency Score', 'Percent Identity', title='Per Column Scores')

# %%
df_clean_25 = df_clean[df_clean['Fraction Aligned'] <= 0.25]
df_clean_25
# Out:
# Empty DataFrame
# Columns: [Identity, Percent Identity, Avg Blosum62 Score, Avg Frequency Score, Fraction Aligned]
# Index: []

# %%
df_clean_50 = df_clean[df_clean['Fraction Aligned'] <= 0.50]
df_clean_50
# Out:
# Empty DataFrame
# Columns: [Identity, Percent Identity, Avg Blosum62 Score, Avg Frequency Score, Fraction Aligned]
# Index: []

# %%
df_clean_75 = df_clean[df_clean['Fraction Aligned'] <= 0.75]
df_clean_75
# Out:
#     Identity  Percent Identity  Avg Blosum62 Score  Avg Frequency Score  \
# 336        x          0.361111           -0.561905             0.583333
#
#      Fraction Aligned
# 336          0.734694
